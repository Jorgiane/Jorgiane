# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorgiane/Jorgiane/blob/main/Trilha_1_Tarefa_(Peso_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://www.gutenberg.org/cache/epub/66447/pg66447.txt'): 
    texto.append(line.decode('utf-8'))



for i in range(len(texto)):
    texto[i] = texto[i].lower() 
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','')

# %%
mydict = {}                             

for line in texto:

  line = line.lower()                  
  words = line.split()                  
  for word in words:                      
    if word not in mydict.keys():         
      mydict[word] = 1                    
    else:                                  
      mydict[word] =  mydict[word] + 1    

print(mydict)
# Out:
# {'\ufeffthe': 1, 'project': 83, 'gutenberg': 25, 'ebook': 12, 'of': 203, 'the': 361, 'aab': 32, 'by': 34, 'edward': 3, 'w': 3, 'ludwig': 3, 'this': 50, 'is': 25, 'for': 39, 'use': 12, 'anyone': 5, 'anywhere': 2, 'in': 96, 'united': 15, 'states': 20, 'and': 113, 'most': 8, 'other': 18, 'parts': 2, 'world': 2, 'at': 24, 'no': 17, 'cost': 3, 'with': 58, 'almost': 2, 'restrictions': 2, 'whatsoever': 2, 'you': 90, 'may': 15, 'copy': 12, 'it': 49, 'give': 4, 'away': 7, 'or': 80, 're-use': 2, 'under': 7, 'terms': 22, 'license': 17, 'included': 3, 'online': 5, 'wwwgutenbergorg': 5, 'if': 26, 'are': 27, 'not': 41, 'located': 7, 'will': 14, 'have': 10, 'to': 142, 'check': 4, 'laws': 10, 'country': 4, 'where': 6, 'before': 6, 'using': 6, 'title:': 1, 'author:': 1, 'release': 1, 'date:': 1, 'october': 1, '2': 2, '2021': 1, '[ebook': 1, '#66447]': 1, 'language:': 1, 'english': 1, 'produced': 3, 'by:': 1, 'greg': 1, 'weeks': 1, 'mary': 1, 'meehan': 1, 'distributed': 4, 'proofreading': 1, 'team': 1
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] 


plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
